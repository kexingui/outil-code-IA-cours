# %% [markdown]
# ## Quiz: Introduction to Matplotlib
#
# ### Question 1: Which of the following best describes the kind of plots Matplotlib is primarily used to create?  C
# A. 3D models
# B. Interactive web maps
# C. 2D graphical plots
# D. Text-based data summaries
#
# ### Question 2: Which of the following commands will display the plot on screen in Matplotlib?  A
# A. plt.show()
# B. plt.figure()
# C. plt.plot()
# D. plt.xlabel()
#
# ### Question 3: How do you add a legend to a plot in Matplotlib?  C
# A. plt.add_legend()
# B. plt.legend()
# C. plt.label()
# D. plt.title()
#
# ### Question 4: In Matplotlib, what does the 'r' in `plt.title(r"Plot of $y=x^2$")` stand for?  A
# A. Reverse
# B. Raw string
# C. Right align
# D. Repeat
#
# ### Question 5: What does the `color` parameter control in a Matplotlib plot?  C
# A. The transparency of plot lines
# B. The thickness of plot lines
# C. The color of plot lines
# D. The style of plot lines
#
# ### Question 6: Which of the following is not a function in Matplotlib for adjusting the appearance of your plot?   D
# A. plt.xlim()
# B. plt.style.use()
# C. plt.set()
# D. plt.savefig()
#
# ### Question 7: What is the purpose of using the `fig.tight_layout()` method in Matplotlib?  C
# A. To prevent overlapping of subplots within a figure
# B. To change the figure's background color
# C. To adjust the size of the figure dynamically
# D. To add a border around the figure
#
# ### Question 8: What does the `plt.figure(figsize=(10, 6))` command do?  B
# A. Creates a figure with a size of 10x6 inches
# B. Creates a figure with a size of 10x6 pixels  1
# C. Creates a figure with a default size
# D. Creates a figure and saves it as a file
#
# ### Question 9: How can you change the scale of the axes in a Matplotlib plot?
# A. By using the `axes()` method
# B. By using the `scale_set()` method
# C. By using the `set_xscale()` and `set_yscale()` methods
# D. By adjusting the `figsize` attribute
#
# ### Question 10: What is the function of the `plt.subplot()` command in Matplotlib?
# A. To create a plot with a specific title
# B. To create separate sections within a single figure, each capable of holding its own plot
# C. To connect multiple plots into one continuous plot
# D. To enhance the resolution of plots
